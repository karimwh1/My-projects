# %%
import pandas as pd

# %%
result = pd.read_csv('full_results.csv')

# %%
result.head(50)
# Out:
#     name      value normalConcentration rangeConcentration  \
# 0    NaN  Increased       180.00-740.00     550.00-1350.00
# 1    NaN  Increased      95.00 - 320.00           830-1360
# 2    NaN  Increased           65.00-215    210.00 - 650.00
# 3    NaN  Increased            25 - 150                NaN
# 4    NaN  Increased         10.00-38.00      56.00 -170.00
# 5    NaN  Increased         10.00-38.00      56.00 -525.00
# 6    NaN  Increased         30.00-88.00    250.00 - 980.00
# 7    NaN  Increased          2.00-33.00    1000.00-1500.00
# 8    NaN  Increased           6.00 - 27     28.00 - 348.00
# 9    NaN  Increased           6.00 - 27    94.00 - 1200.00
# 10   NaN  Increased         10.00-45.00     42.00 - 190.00
# 11   NaN  Decreased           6.00 - 27        4.50 - 5.00
# 12   NaN  Decreased           6.00 - 27        1.80 - 6.00
# 13   NaN  Increased           6.00 - 27    108.00 - 290.00
# 14   NaN  Increased        35.00-218.00      100.00-500.00
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 93 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           0 non-null      float64
#  1   value                          115 non-null    object
#  2   normalConcentration            115 non-null    object
#  3   rangeConcentration             114 non-null    object
#  4   reference                      115 non-null    object
#  5   ramedis                        26 non-null     object
#  6   metabolite.met_id              115 non-null    int64
#  7   metabolite.abbreviation        115 non-null    object
#  8   metabolite.createdDate         115 non-null    object
#  9   metabolite.updatedDate         115 non-null    object
#  10  metabolite.fullName            115 non-null    object
#  11  metabolite.description         66 non-null     object
# ...
