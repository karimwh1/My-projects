# %%
metabo = pd.read_csv('metabolites.csv')
chebi = pd.read_csv('chebild_final_fs.tsv',sep='\t')

# %%
import pandas as pd

# %%
metabo_b = metabo.fillna("m")
chebi_c = chebi.fillna("c")
metabo_b.to_csv('metabo_b.csv',index_label=False)
chebi_c.to_csv('chebi_c.csv',index_label=False)

# %%
metabo_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5607 entries, 0 to 5606
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   abbreviation_metabolite  5607 non-null   object
#  1   casregistry_metabolite   5607 non-null   object
#  2   cheblid_metabolite       5607 non-null   object
#  3   description_metabolite   5607 non-null   object
#  4   fullname_metabolite      5607 non-null   object
#  5   hmdb_metabolite          5607 non-null   object
#  6   inchikey_metabolite      5607 non-null   object
#  7   inchistring_metabolite   5607 non-null   object
#  8   keggid_metabolite        5607 non-null   object
#  9   biocyc_metabolite        5607 non-null   object
#  10  food_db_metabolite       5607 non-null   object
#  11  reconmap3_metabolite     5607 non-null   object
#  12  smile_metabolite         5607 non-null   object
#  13  inchiKey_metabolite      5607 non-null   object
# ...

# %%
metabo_b.duplicated().sum()
# Out:
# 0

# %%
chebi_c.head(20)
# Out:
#     CHEBI_ID                                              InChI  \
# 0         90  InChI=1S/C15H14O6/c16-8-4-11(18)9-6-13(20)15(2...
# 1         90  InChI=1S/C15H14O6/c16-8-4-11(18)9-6-13(20)15(2...
# 2        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 3        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 4        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 5        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 6        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 7        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 8        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 9        165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 10       165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 11       165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 12       165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# 13       165  InChI=1S/C10H16O/c1-9(2)7-4-5-10(3,6-7)8(9)11/...
# ...

# %%
chebi_matabo =metabo_b.merge(chebi_c,left_on='inchiString_metabolite',right_on='InChI',how='inner')

# %% [markdown]
# As you can see the "11docrtsl" is duplictated cross multiple columns but different on the last 4 columns starting with id which is the chebi id btw.
# in advance I also checked if the metabo is duplicated due to my mistake in iterating through the api pages.
# I also used a completly different letter in the metabo ( m instead of b )

# %%
chebi_matabo.head(20)
# Out:
#    abbreviation_metabolite casregistry_metabolite cheblid_metabolite  \
# 0                11docrtsl               152-58-9                  m
# 1                11docrtsl               152-58-9                  m
# 2                11docrtsl               152-58-9                  m
# 3                11docrtsl               152-58-9                  m
# 4                11docrtsl               152-58-9                  m
# 5                11docrtsl               152-58-9                  m
# 6              11docrtstrn                64-85-7            16973.0
# 7              11docrtstrn                64-85-7            16973.0
# 8              11docrtstrn                64-85-7            16973.0
# 9              11docrtstrn                64-85-7            16973.0
# 10             11docrtstrn                64-85-7            16973.0
# 11             11docrtstrn                64-85-7            16973.0
# 12             11docrtstrn                64-85-7            16973.0
# ...
