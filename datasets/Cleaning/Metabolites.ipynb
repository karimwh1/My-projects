# %%
import pandas as pd

# %%
metabo = pd.read_csv('metabolites.csv')

# %%
metabo.head(100)
# Out:
#    casregistry_metabolite  cheblid_metabolite  \
# 0               2800-34-2             15637.0
# 1                     NaN                 NaN
# 2                     NaN                 NaN
# 3                     NaN                 NaN
# 4                     NaN                 NaN
# 5                     NaN                 NaN
# 6                     NaN                 NaN
# 7                     NaN                 NaN
# 8                     NaN                 NaN
# 9                     NaN                 NaN
# 10                    NaN                 NaN
# 11                    NaN                 NaN
# 12                    NaN                 NaN
# 13               152-58-9                 NaN
# 14                64-85-7             16973.0
# 15                    NaN                 NaN
# 16                    NaN                 NaN
# 17                    NaN                 NaN
# 18                    NaN                 NaN
# ...

# %%
metabo.duplicated().sum()
# Out:
# 5600

# %%
metabo.drop_duplicates(inplace=True)

# %%
metabo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   casregistry_metabolite  7 non-null      object
#  1   cheblid_metabolite      5 non-null      float64
#  2   description_metabolite  8 non-null      object
#  3   fullName_metabolite     50 non-null     object
#  4   hmdb_metabolite         10 non-null     object
#  5   inchiKey_metabolite     13 non-null     object
#  6   inchiString_metabolite  13 non-null     object
#  7   keggid_metabolite       6 non-null      object
#  8   biocyc_metabolite       5 non-null      object
#  9   food_db_metabolite      7 non-null      object
#  10  reconmap3_metabolite    14 non-null     object
#  11  smile_metabolite        13 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 5.1+ KB
