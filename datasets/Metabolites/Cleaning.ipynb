# %%
import pandas as pd

# %%
metabo = pd.read_csv('metabolites_syn.csv')

# %%
metabo.head(30)
# Out:
#    abbreviation_metabolite casregistry_metabolite  cheblid_metabolite  \
# 0                   10fthf              2800-34-2             15637.0
# 1               10fthf5glu                    NaN                 NaN
# 2               10fthf6glu                    NaN                 NaN
# 3               10fthf7glu                    NaN                 NaN
# 4             10m3hddcaACP                    NaN                 NaN
# 5            10m3hundecACP                    NaN                 NaN
# 6             10m3oddcaACP                    NaN                 NaN
# 7            10m3oundecACP                    NaN                 NaN
# 8               10mddcaACP                    NaN                 NaN
# 9            10mtddec2eACP                    NaN                 NaN
# 10          10mtundec2eACP                    NaN                 NaN
# 11             10mundecACP                    NaN                 NaN
# ...

# %%
metabo.duplicated().sum()
# Out:
# 0
