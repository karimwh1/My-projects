# %%
import pandas as pd

# %%
dataset_cas = pd.read_csv('metabo_chebi_cas.csv')
dataset_hmdb = pd.read_csv('metabo_chebi_hmdb.csv')
dataset_inchi = pd.read_csv('metabo_chebi_inchi.csv')
dataset_kegg = pd.read_csv('metabo_chebi_kegg.csv')
dataset_syn = pd.read_csv('metabo_syn_cheb.csv')

# %%
dataset_cas.head(20)
# Out:
#     chebi                                name  \
# 0    4917                             eugenol
# 1    8055  5-methylphenazinium methyl sulfate
# 2   73492                         Glu-Glu-Ile
# 3   29449                      hydrogen azide
# 4    8212                            pimozide
# 5    5262                            galangin
# 6    7863         oxymetazoline hydrochloride
# 7   11892          N-carbamoyl-beta-alaninate
# 8   89891                          3-hexanone
# 9    3388         carbamazepine-10,11-epoxide
# 10   7968                    penicilloic acid
# 11   7497                 nelfinavir mesylate
# 12   6899        metoclopramide hydrochloride
# 13  72801                              5-HEPE
# 14   8892               rosiglitazone maleate
# 15  84370                      cladoniamide E
# 16  18961        1-(3-aminopropyl)pyrrolinium
# 17   5395                        glucoalyssin
# 18  19227                  2'-O-methyluridine
# ...

# %%
dataset_inchi.drop(columns={'inchikey_metabolite','inchistring_metabolite','SOURCE'},inplace=True)

# %%
dataset_inchi.rename.str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 dataset_inchi.rename.str.lower()
#
# AttributeError: 'function' object has no attribute 'str'

# %%
dataset_inchi.columns = dataset_inchi.columns.str.lower()

# %%
dataset_inchi.head(100)
# Out:
#    abbreviation_metabolite casregistry_metabolite cheblid_metabolite  \
# 0                11docrtsl               152-58-9                  b
# 1              11docrtstrn                64-85-7            16973.0
# 2                  12ppd_R                57-55-6            16997.0
# 3                  12ppd_S              4254-15-3            29002.0
# 4                  13dampp               109-76-2            15725.0
# ..                     ...                    ...                ...
# 95                  3dpdhb                      b            62793.0
# 96               3dpdhb_me                      b            62796.0
# 97                   3dphb                      b                  b
# 98                 3dsphgn             16105-69-4            17862.0
# 99                 3h3mglt                      b            17325.0
#
#                                description_metabolite  \
# 0   Human Metabolome Database (HMDB): Cortexolone ...
# ...

# %%
dataset_cas.head()
# Out:
#    chebi                                name  \
# 0   4917                             eugenol
# 1   8055  5-methylphenazinium methyl sulfate
# 2  73492                         Glu-Glu-Ile
# 3  29449                      hydrogen azide
# 4   8212                            pimozide
#
#                                           definition  compound_id  \
# 0  A phenylpropanoid formally derived from guaiac...        17254
# 1                                                  a        17296
# 2  A tripeptide composed of two L-glutamic acid u...        17296
# 3                                                  a        16393
# 4  A member of the class of benzimidazoles that i...        15843
#
#                   type accession_number abbreviation_metabolite  \
# 0  CAS Registry Number         452-86-8                   4mcat
# 1  CAS Registry Number          62-53-3                  M01341
# 2  CAS Registry Number          62-53-3                  M01341
# ...

# %%
dataset_cas.drop(columns={'inchikey_metabolite','inchistring_metabolite','type'},inplace=True)

# %%
dataset_cas.head(100)
# Out:
#     chebi                                            name  \
# 0    4917                                         eugenol
# 1    8055              5-methylphenazinium methyl sulfate
# 2   73492                                     Glu-Glu-Ile
# 3   29449                                  hydrogen azide
# 4    8212                                        pimozide
# ..    ...                                             ...
# 95   5635                                       helenalin
# 96  71192                        N-(cyanomethyl)glycinate
# 97   3081                                    betavulgarin
# 98    108                                   (-)-phaseolin
# 99  84306  (13Z,16Z,19Z,22Z)-2-hydroxyoctacosatetraenoate
#
#                                            definition  compound_id  \
# 0   A phenylpropanoid formally derived from guaiac...        17254
# 1                                                   a        17296
# ...

# %%
dataset_hmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 0 to 0
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   chebi                    1 non-null      int64
#  1   name                     1 non-null      object
#  2   definition               1 non-null      object
#  3   compound_id              1 non-null      int64
#  4   type                     1 non-null      object
#  5   accession_number         1 non-null      object
#  6   abbreviation_metabolite  1 non-null      object
#  7   casregistry_metabolite   1 non-null      object
#  8   cheblid_metabolite       1 non-null      float64
#  9   description_metabolite   1 non-null      object
#  10  fullname_metabolite      1 non-null      object
#  11  hmdb_metabolite          1 non-null      object
#  12  inchikey_metabolite      1 non-null      object
#  13  inchistring_metabolite   1 non-null      object
# ...

# %%
dataset_syn.head(12)
# Out:
#     CHEBI_ID                                              InChI  \
# 0      15772  InChI=1S/C9H7NO4/c11-7-2-4-1-6(9(13)14)10-5(4)...
# 1      28099  InChI=1S/C20H30O4/c1-2-3-6-9-17(21)14-12-16-13...
# 2     133391  InChI=1S/C20H30O4/c1-2-3-6-9-17(21)14-12-16-13...
# 3      28883  InChI=1S/C9H7NO2/c11-7-4-5-10-9-6(7)2-1-3-8(9)...
# 4      28920  InChI=1S/C14H24N2O9/c1-5(13(21)22)15-12(20)6(2...
# 5      48092  InChI=1S/C5H10O6/c6-1-2(7)3(8)4(9)5(10)11/h2-4...
# 6        783  InChI=1S/C27H46O3/c1-18(2)7-6-13-26(5,29)27(30...
# 7      31529  InChI=1S/C10H17NO3/c1-11-6-3-4-7(11)9(8(12)5-6...
# 8      31529  InChI=1S/C10H17NO3/c1-11-6-3-4-7(11)9(8(12)5-6...
# 9      63843  InChI=1S/C21H30O3/c1-13(22)21(24)11-8-18-16-5-...
# 10     64685                        InChI=1S/CH4Se/c1-2/h2H,1H3
# 11     73406  InChI=1S/C8H14N4O5/c9-3(1-5(10)13)7(15)12-4(8(...
#
#            SOURCE                                 name_x  \
# 0           ChEBI                           L-dopachrome
# ...
